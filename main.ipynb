# %%
import sys
sys.path.append('../')

from documentador_sphinx import DocumentadorSphinx

"""
Nessa celula é necessário adicionar o caminho do projeto que deseja documentar.
"""
source_dir = r'../'
# source_dir = r'caminho do source'
sphinx_docs = DocumentadorSphinx(source_dir)

# %%
"""
Rodar essa celula, caso queira gerar a documentação do projeto.
"""

sphinx_docs.gerar_documentacao()
sphinx_docs.construir_html()

# %%
"""
Rodar essa celula, caso queira mudar o nome do projeto
"""
sphinx_docs.mudar_nome_projeto(nome_projeto='Teste')

# %%
"""
Rodar essa celula, caso queira adicionar um documento à documentação. A função irá solicitar um documento com extensão .md e uma descrição referente a esse documento.
"""
sphinx_docs.adicionar_documento(descricao='Quickstart para teste')

# %%
"""
Rodar essa celula, caso queira deletar um documento da documentação.
"""

sphinx_docs.deletar_documento(nome_arquivo='quickstart')
